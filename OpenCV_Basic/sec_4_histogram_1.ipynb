# %%
# HISTOGRAMS

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
horse = cv2.imread('/home/srijanani/GIT/OpenCV/Images/horse.jpg')
show_horse = cv2.cvtColor(horse, cv2.COLOR_BGR2RGB)

rainbow = cv2.imread('/home/srijanani/GIT/OpenCV/Images/rainbow.jpeg')
show_rainbow = cv2.cvtColor(rainbow, cv2.COLOR_BGR2RGB)

bricks = cv2.imread('/home/srijanani/GIT/OpenCV/Images/bricks.jpg')
show_bricks = cv2.cvtColor(bricks, cv2.COLOR_BGR2RGB)

# %%
# DISPLYING HORSE IMAGE

# plt.imshow(show_horse)

# %%
# DISPLAYING RAINBOW IMAGE

plt.imshow(show_rainbow)

# %%
# DISPLAYING BRICKS IMAGE

plt.imshow(show_bricks)
