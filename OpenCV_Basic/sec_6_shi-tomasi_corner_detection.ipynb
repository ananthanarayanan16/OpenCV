# %%
# CORNER DETECTION USING SHI-TOMASI ALGORITHM

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread('/home/srijanani/GIT/OpenCV/Images/flat_chessboard.jpg')
flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_BGR2RGB)

plt.imshow(flat_chess)

# %%
real_chess = cv2.imread('/home/srijanani/GIT/OpenCV/Images/chessboard.jpg')
real_chess = cv2.cvtColor(real_chess, cv2.COLOR_BGR2RGB)

plt.imshow(real_chess)

# %%
# CONVERTING THE IMAGES COLOR INTO GRAY SCALE

gray_flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_RGB2GRAY)

gray_real_chess = cv2.cvtColor(real_chess, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(gray_flat_chess, cmap='gray')

# %%
plt.imshow(gray_real_chess, cmap='gray')

# %%
corner = cv2.goodFeaturesToTrack(gray_flat_chess, 64, 0.01, 10)

# %%
# corner

# %%
# CONVERTING THE FLOAT INTO INT

corner = np.int32(corner)

# %%
for i in corner:

    x,y = i.ravel()
    cv2.circle(flat_chess, (x,y), 3, (255, 0, 0), -1)

# %%
plt.imshow(flat_chess, cmap='gray')

# %%
# USING SHI-TOMASI ALGORITHM IN REAL CHESS IMAGE

corner = cv2.goodFeaturesToTrack(gray_real_chess, 10, 0.04, 10)

# %%
corner = np.int32(corner)

# %%
for i in corner:

    x,y = i.ravel()
    cv2.circle(real_chess, (x,y), 8, (0, 255, 0), -1)

# %%
plt.imshow(real_chess)
