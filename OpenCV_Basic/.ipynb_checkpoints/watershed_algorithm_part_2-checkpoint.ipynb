# %%
# WATERSHED ALGORITHM

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def display(image, cmap='gray'):

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111)
    ax.imshow(image, cmap='gray')

# %%
img = cv2.imread('/home/srijanani/GIT/OpenCV/Images/coins.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
img.shape
# Out:
# (901, 1200, 3)

# %%
img = cv2.medianBlur(img, 35)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (901, 1200, 3)

# %%
# img = cv2.cvtColor(img)

plt.imshow(img)

# %%
img.shape
# Out:
# (901, 1200)
