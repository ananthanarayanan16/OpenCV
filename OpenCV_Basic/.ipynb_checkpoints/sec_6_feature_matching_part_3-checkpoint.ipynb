# %%
# FEATURE MATCHING USE FLANN MATCHER

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def display(image, cmap='gray'):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(image, cmap='gray')

# %%
reeses = cv2.imread('/home/srijanani/GIT/OpenCV/Images/reeses.png', 0)

display(reeses, cmap='gray')

# %%
cereals = cv2.imread('/home/srijanani/GIT/OpenCV/Images/cereals.jpg', 0)

display(cereals, cmap='gray')

# %%
sift = cv2.SIFT_create()

# %%
kp1, des1 = sift.detectAndCompute(reeses, None)

kp2, des2 = sift.detectAndCompute(cereals, None)

# %%
# FLANN

FLANN_INDEX_KDTREE = 0
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(check=50)

# %%
flann = cv2.FlannBasedMatcher(index_params, search_params)

# %%
matcher = flann.knnMatch(des1, des2, k=2)

# %%
matches_mask = [[0, 0] for i in range(len(matcher))]

# %%
good = []

for m, n in matcher:

    if m.distance < 0.75 * n.distance:

        good.append([m])

# for i,(m, n) in enumerate(matcher):

#     if m.distance < 0.75 * n.distance:

#         matches_mask[i] = [1, 0]

# %%
# draw_params = dict(matchcolor=(0, 255, 0),
#                   singlePointcolor=(255, 0, 0),
#                    matches_mask=None,
#                    flags=0)

# %%
# flann_matcher = cv2.drawMatchesKnn(reeses, kp1, cereals, kp2, good, None, *draw_params)

flann_matcher = cv2.drawMatchesKnn(reeses, kp1, cereals, kp2, good, None, flags=0)

# %%
display(flann_matcher)
