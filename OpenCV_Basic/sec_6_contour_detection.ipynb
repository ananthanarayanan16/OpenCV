# %%
# CONTOUR DETECTION

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('/home/srijanani/GIT/OpenCV/Images/cookies.jpeg', 0)

# %%
plt.imshow(img, cmap='gray')

# %%
img.shape
# Out:
# (165, 306)
