# %%
# CUSTOM SEED 

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('/home/srijanani/GIT/OpenCV/Images/road.jpeg')

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# cv2.imshow('Image', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.imshow(img)
