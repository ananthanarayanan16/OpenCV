# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_1 = cv2.imread('/home/srijanani/GIT/OpenCV/Images/puppy.jpeg')
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

img_2 = cv2.imread('/home/srijanani/GIT/OpenCV/Images/home.jpeg')
img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
plt.imshow(img_2)

# %%
img_1.shape
# Out:
# (168, 300, 3)

# %%
img_2.shape
# Out:
# (386, 580, 3)

# %%
# BLENDING IMAGE WITH SAME SIZE
# RESIZING THE IMAGES USING THE RESIZE FUNCTION

img_1 = cv2.resize(img_1, (300, 300))

img_2 = cv2.resize(img_2, (300, 300))

img_1.shape
# Out:
# (300, 300, 3)

# %%
img_2.shape
# Out:
# (300, 300, 3)

# %%
# AFTER RESIZING THE FIRST IMAGE

plt.imshow(img_1)

# %%
# AFTER RESIZING THE SECOND IMAGE

plt.imshow(img_2)

# %%
# BLENDING THE IMAGE USING ADD WEIGHT FUNTION

blended = cv2.addWeighted(src1=img_1,alpha=0.5,src2=img_2,beta=0.5,gamma=1)

plt.imshow(blended)

# %%
img_1 = cv2.imread('/home/srijanani/GIT/OpenCV/Images/puppy.jpeg')
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

img_2 = cv2.imread('/home/srijanani/GIT/OpenCV/Images/home.jpeg')
img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
plt.imshow(img_2)

# %%
# RESIZING THE SECOND IMAGE

img_2 = cv2.resize(img_2, (100, 100))

plt.imshow(img_2)

# %%
large_img = img_1

small_img = img_2

x_start = 0

y_start = 0

x_end = x_start + small_img.shape[1]

y_end = y_start + small_img.shape[0]

small_img.shape
# Out:
# (100, 100, 3)

# %%
large_img[y_start : y_end, x_start : x_end] = small_img

plt.imshow(large_img)
