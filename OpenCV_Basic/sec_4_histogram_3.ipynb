# %%
# HISTOGRAM EQULIZATION

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def display(img, cmap=None):
    fig = plt.figure(figsize=(8,6))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap)

# %%
gorilla = cv2.imread('/home/srijanani/GIT/OpenCV/Images/gorilla.jpeg', 0)

# %%
display(gorilla, cmap='gray')

# %%
gorilla.shape
# Out:
# (1987, 3000)

# %%
hist_value = cv2.calcHist([gorilla], channels=[0], mask=None, histSize=[256], ranges=[0, 256])

# %%
plt.plot(hist_value)

# %%
# USING THE HISTOGRAM EQULIZATION FNCTION

eq_gorilla = cv2.equalizeHist(gorilla)

# %%
display(eq_gorilla, cmap='gray')

# %%
hist_value = cv2.calcHist([eq_gorilla], channels=[0], mask=None, histSize=[256], ranges=[0, 256])

plt.plot(hist_value)
plt.title('HISTOGRAM FOR EQUALIZATION GORILLA')
# Out:
# Text(0.5, 1.0, 'HISTOGRAM FOR EQUALIZATION GORILLA')

# %%
color_gorilla = cv2.imread('/home/srijanani/GIT/OpenCV/Images/gorilla.jpeg')

show_gorilla = cv2.cvtColor(color_gorilla, cv2.COLOR_BGR2RGB)  # CONVERT THE IMAGE BGR TO RGB COLOR

# %%
plt.imshow(show_gorilla)

# %%
# CONVERTING THE RGB COLOR IMAGE TO HSV COLOR IMAGE

hsv = cv2.cvtColor(color_gorilla, cv2.COLOR_RGB2HSV)

# %%
# plt.imshow(hsv)

# %%
hsv[:, :, 2].max()
# Out:
# np.uint8(255)

# %%
hsv[:, :, 2] = cv2.equalizeHist(hsv[:, :, 2])

# %%
# plt.imshow(hsv)

# %%
eq_color_gorilla = cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)

# %%
plt.imshow(eq_color_gorilla)

# %%
hist_value_eq_gorilla = cv2.calcHist([eq_gorilla], channels=[0], mask=None, histSize=[256], ranges=[0, 256])

# %%
# plt.plot(hist_value_eq_gorilla)
